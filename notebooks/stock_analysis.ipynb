# %% [markdown]
# # Preparing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_aapl = pd.read_csv("../data/raw/yfinance_data/Data/AAPL.csv")
df_amzn = pd.read_csv("../data/raw/yfinance_data/Data/AMZN.csv")
df_goog = pd.read_csv("../data/raw/yfinance_data/Data/GOOG.csv")
df_meta = pd.read_csv("../data/raw/yfinance_data/Data/META.csv")
df_nvda = pd.read_csv("../data/raw/yfinance_data/Data/NVDA.csv")

print("AAPL")
display(df_aapl.head())

print("AMZN")
display(df_amzn.head())

print("GOOG")
display(df_goog.head())

print("META")
display(df_meta.head())

print("NVDA")
display(df_nvda.head())
# Out:
# AAPL
#          Date     Close      High       Low      Open      Volume
# 0  2009-01-02  2.721686  2.730385  2.554037  2.575630   746015200
# 1  2009-01-05  2.836553  2.884539  2.780469  2.794266  1181608400
# 2  2009-01-06  2.789767  2.914229  2.770872  2.877641  1289310400
# 3  2009-01-07  2.729484  2.774170  2.706990  2.753477   753048800
# 4  2009-01-08  2.780169  2.793666  2.700393  2.712090   673500800
# AMZN
#          Date  Close    High     Low    Open     Volume
# 0  2009-01-02  2.718  2.7265  2.5535  2.5675  145928000
# 1  2009-01-05  2.703  2.7870  2.6515  2.7865  190196000
# 2  2009-01-06  2.868  2.9110  2.6875  2.7275  221602000
# 3  2009-01-07  2.810  2.8475  2.7675  2.8145  158854000
# 4  2009-01-08  2.858  2.8660  2.7290  2.7495  131558000
# GOOG
#          Date     Close      High       Low      Open     Volume
# 0  2009-01-02  7.948608  7.960977  7.557264  7.633949  144961322
# 1  2009-01-05  8.115089  8.194003  7.792268  7.940692  196293007
# 2  2009-01-06  8.263762  8.430492  8.074027  8.237046  257971329
# 3  2009-01-07  7.965677  8.185839  7.885034  8.121770  180453860
# 4  2009-01-08  8.044340  8.044340  7.850152  7.873406  144567852
# META
#          Date      Close       High        Low       Open     Volume
# 0  2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 1  2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2  2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 3  2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 4  2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200
# NVDA
#          Date     Close      High       Low      Open      Volume
# 0  2009-01-02  0.199652  0.201027  0.184294  0.184982   497124000
# 1  2009-01-05  0.203319  0.207904  0.195984  0.197360   705736000
# 2  2009-01-06  0.210196  0.216156  0.204695  0.209279   657904000
# 3  2009-01-07  0.197589  0.205382  0.190483  0.205382   870096000
# 4  2009-01-08  0.192546  0.195067  0.180626  0.195067  1014496000

# %%
print("AAPL")
df_aapl.info()

print("\nAMZN")
df_amzn.info()

print("\nGOOG")
df_goog.info()

print("\nMETA")
df_meta.info()

print("\nNVDA")
df_nvda.info()
# Out:
# AAPL
# <class 'pandas.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3774 non-null   str
#  1   Close   3774 non-null   float64
#  2   High    3774 non-null   float64
#  3   Low     3774 non-null   float64
#  4   Open    3774 non-null   float64
#  5   Volume  3774 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 177.0 KB
#
# AMZN
# <class 'pandas.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3774 non-null   str
#  1   Close   3774 non-null   float64
#  2   High    3774 non-null   float64
#  3   Low     3774 non-null   float64
#  4   Open    3774 non-null   float64
#  5   Volume  3774 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 177.0 KB
#
# GOOG
# <class 'pandas.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3774 non-null   str
#  1   Close   3774 non-null   float64
#  2   High    3774 non-null   float64
#  3   Low     3774 non-null   float64
#  4   Open    3774 non-null   float64
#  5   Volume  3774 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 177.0 KB
#
# META
# <class 'pandas.DataFrame'>
# RangeIndex: 2923 entries, 0 to 2922
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2923 non-null   str
#  1   Close   2923 non-null   float64
#  2   High    2923 non-null   float64
#  3   Low     2923 non-null   float64
#  4   Open    2923 non-null   float64
#  5   Volume  2923 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 137.1 KB
#
# NVDA
# <class 'pandas.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3774 non-null   str
#  1   Close   3774 non-null   float64
#  2   High    3774 non-null   float64
#  3   Low     3774 non-null   float64
#  4   Open    3774 non-null   float64
#  5   Volume  3774 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 177.0 KB

# %%
print("AAPL")
print(df_aapl.isna().sum())

print("\nAMZN")
print(df_amzn.isna().sum())

print("\nGOOG")
print(df_goog.isna().sum())

print("\nMETA")
print(df_meta.isna().sum())

print("\nNVDA")
print(df_nvda.isna().sum())
# Out:
# AAPL
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64
#
# AMZN
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64
#
# GOOG
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64
#
# META
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64
#
# NVDA
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %% [markdown]
# No missing values were found in any of the datasets, and all columns contain data in the correct format. So no cleaning is needed.

# %% [markdown]
# # Technical Indicators

# %%
stocks = {
    "AAPL": df_aapl,
    "AMZN": df_amzn,
    "GOOG": df_goog,
    "META": df_meta,
    "NVDA": df_nvda
}

from ta.trend import SMAIndicator, EMAIndicator, MACD
from ta.momentum import RSIIndicator

for name, df in stocks.items():
    
    # Moving Averages
    df["SMA_20"] = SMAIndicator(close=df["Close"], window=20).sma_indicator()
    df["EMA_20"] = EMAIndicator(close=df["Close"], window=20).ema_indicator()
    
    # RSI
    df["RSI"] = RSIIndicator(close=df["Close"], window=14).rsi()
    
    # MACD
    macd = MACD(close=df["Close"])
    df["MACD"] = macd.macd()
    df["MACD_signal"] = macd.macd_signal()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(16, 12))
axes = axes.flatten()

stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for i, name in enumerate(stock_list):
    df = stocks[name]
    
    # filter to last 1 year for clarity
    df_filtered = df.iloc[-365:]
    
    axes[i].plot(df_filtered.index, df_filtered["Close"], label="Close", linewidth=1)
    axes[i].plot(df_filtered.index, df_filtered["SMA_20"], label="SMA 20")
    axes[i].plot(df_filtered.index, df_filtered["EMA_20"], label="EMA 20")
    
    axes[i].set_title(f"{name} - Moving Averages (Last 1 Year)")
    axes[i].legend()

axes[-1].axis("off")

plt.tight_layout()
plt.show()

# %%
stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for name in stock_list:
    df = stocks[name].dropna(subset=["SMA_20", "EMA_20"])
    
    above_sma = (df["Close"] > df["SMA_20"]).sum()
    below_sma = (df["Close"] <= df["SMA_20"]).sum()
    
    pct_above = above_sma / len(df) * 100
    
    last_close = df["Close"].iloc[-1]
    last_sma = df["SMA_20"].iloc[-1]
    
    current_pos = "ABOVE" if last_close > last_sma else "BELOW"
    gap_pct = abs((last_close - last_sma) / last_sma * 100)
    
    print("\n" + "=" * 60)
    print(f"{name} - MOVING AVERAGE INTERPRETATION")
    print("=" * 60)
    
    print(f"Days ABOVE SMA: {above_sma} ({pct_above:.1f}%)")
    print(f"Days BELOW SMA: {below_sma} ({100 - pct_above:.1f}%)")
    print()
    
    print(f"Last Close: {last_close:.2f}")
    print(f"SMA 20: {last_sma:.2f}")
    print(f"Current position: {current_pos} by {gap_pct:.2f}%")
    print()
    
    if pct_above > 60:
        print("Trend: Strong bullish bias (buyers dominant)")
    elif pct_above > 40:
        print("Trend: Sideways / indecisive market")
    else:
        print("Trend: Bearish bias (selling pressure dominant)")
    
    if current_pos == "ABOVE":
        print("Short-term signal: UPWARD momentum")
    else:
        print("Short-term signal: DOWNWARD momentum")
# Out:
# ============================================================
# AAPL - MOVING AVERAGE INTERPRETATION
# ============================================================
# Days ABOVE SMA: 2381 (63.4%)
# Days BELOW SMA: 1374 (36.6%)
#
# Last Close: 190.73
# SMA 20: 192.49
# Current position: BELOW by 0.92%
#
# Trend: Strong bullish bias (buyers dominant)
# Short-term signal: DOWNWARD momentum
#
# ============================================================
# AMZN - MOVING AVERAGE INTERPRETATION
# ============================================================
# Days ABOVE SMA: 2299 (61.2%)
# Days BELOW SMA: 1456 (38.8%)
#
# Last Close: 151.94
# SMA 20: 149.82
# Current position: ABOVE by 1.41%
#
# Trend: Strong bullish bias (buyers dominant)
# Short-term signal: UPWARD momentum
#
# ============================================================
# GOOG - MOVING AVERAGE INTERPRETATION
# ============================================================
# Days ABOVE SMA: 2250 (59.9%)
# Days BELOW SMA: 1505 (40.1%)
#
# Last Close: 139.97
# SMA 20: 135.98
# Current position: ABOVE by 2.94%
#
# Trend: Sideways / indecisive market
# Short-term signal: UPWARD momentum
#
# ============================================================
# META - MOVING AVERAGE INTERPRETATION
# ============================================================
# Days ABOVE SMA: 1783 (61.4%)
# Days BELOW SMA: 1121 (38.6%)
#
# Last Close: 351.79
# SMA 20: 336.87
# Current position: ABOVE by 4.43%
#
# Trend: Strong bullish bias (buyers dominant)
# Short-term signal: UPWARD momentum
#
# ============================================================
# NVDA - MOVING AVERAGE INTERPRETATION
# ============================================================
# Days ABOVE SMA: 2285 (60.9%)
# Days BELOW SMA: 1470 (39.1%)
#
# Last Close: 49.50
# SMA 20: 48.05
# Current position: ABOVE by 3.02%
#
# Trend: Strong bullish bias (buyers dominant)
# Short-term signal: UPWARD momentum

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(16, 12))
axes = axes.flatten()

stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for i, name in enumerate(stock_list):
    df = stocks[name]
    
    axes[i].plot(df.index, df["RSI"], label="RSI")
    
    axes[i].axhline(70, linestyle="--", color="red", linewidth=1)
    axes[i].axhline(30, linestyle="--", color="green", linewidth=1)
    
    axes[i].set_title(f"{name} - RSI")
    axes[i].legend()

# turn off empty subplot (6th slot)
axes[-1].axis("off")

plt.tight_layout()
plt.show()

# %%
stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for name in stock_list:
    df = stocks[name].dropna(subset=["RSI"])
    
    overbought = (df["RSI"] > 70).sum()
    oversold = (df["RSI"] < 30).sum()
    neutral = ((df["RSI"] >= 30) & (df["RSI"] <= 70)).sum()
    
    total = len(df)
    
    print("\n" + "=" * 60)
    print(f"{name} - RSI INTERPRETATION")
    print("=" * 60)
    
    print(f"Overbought days (RSI > 70): {overbought} ({overbought/total*100:.1f}%)")
    print(f"Oversold days (RSI < 30): {oversold} ({oversold/total*100:.1f}%)")
    print(f"Neutral days: {neutral} ({neutral/total*100:.1f}%)")
    print()
    
    last_rsi = df["RSI"].iloc[-1]
    print(f"Current RSI: {last_rsi:.2f}")
    
    if last_rsi > 70:
        print("Signal: Overbought -> possible pullback or correction")
    elif last_rsi < 30:
        print("Signal: Oversold -> possible rebound or recovery")
    else:
        print("Signal: Neutral -> no extreme momentum condition")
# Out:
# ============================================================
# AAPL - RSI INTERPRETATION
# ============================================================
# Overbought days (RSI > 70): 575 (15.3%)
# Oversold days (RSI < 30): 68 (1.8%)
# Neutral days: 3118 (82.9%)
#
# Current RSI: 51.12
# Signal: Neutral -> no extreme momentum condition
#
# ============================================================
# AMZN - RSI INTERPRETATION
# ============================================================
# Overbought days (RSI > 70): 342 (9.1%)
# Oversold days (RSI < 30): 48 (1.3%)
# Neutral days: 3371 (89.6%)
#
# Current RSI: 59.01
# Signal: Neutral -> no extreme momentum condition
#
# ============================================================
# GOOG - RSI INTERPRETATION
# ============================================================
# Overbought days (RSI > 70): 388 (10.3%)
# Oversold days (RSI < 30): 68 (1.8%)
# Neutral days: 3305 (87.9%)
#
# Current RSI: 59.31
# Signal: Neutral -> no extreme momentum condition
#
# ============================================================
# META - RSI INTERPRETATION
# ============================================================
# Overbought days (RSI > 70): 236 (8.1%)
# Oversold days (RSI < 30): 73 (2.5%)
# Neutral days: 2601 (89.4%)
#
# Current RSI: 64.30
# Signal: Neutral -> no extreme momentum condition
#
# ============================================================
# NVDA - RSI INTERPRETATION
# ============================================================
# Overbought days (RSI > 70): 447 (11.9%)
# Oversold days (RSI < 30): 74 (2.0%)
# Neutral days: 3240 (86.1%)
#
# Current RSI: 58.31
# Signal: Neutral -> no extreme momentum condition

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(16, 12))
axes = axes.flatten()

stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for i, name in enumerate(stock_list):
    df = stocks[name]
    
    axes[i].plot(df.index, df["MACD"], label="MACD")
    axes[i].plot(df.index, df["MACD_signal"], label="Signal")
    
    axes[i].set_title(f"{name} - MACD")
    axes[i].legend()

# turn off empty subplot
axes[-1].axis("off")

plt.tight_layout()
plt.show()

# %%
stock_list = ["AAPL", "AMZN", "GOOG", "META", "NVDA"]

for name in stock_list:
    df = stocks[name].dropna(subset=["MACD", "MACD_signal"])
    
    # when MACD is above signal line
    bullish_periods = (df["MACD"] > df["MACD_signal"]).sum()
    
    # when MACD is below signal line
    bearish_periods = (df["MACD"] < df["MACD_signal"]).sum()
    
    total = len(df)
    
    print("\n" + "=" * 60)
    print(f"{name} - MACD INTERPRETATION")
    print("=" * 60)
    
    print(f"Bullish periods (MACD > Signal): {bullish_periods} ({bullish_periods/total*100:.1f}%)")
    print(f"Bearish periods (MACD < Signal): {bearish_periods} ({bearish_periods/total*100:.1f}%)")
    print()
    
    last_macd = df["MACD"].iloc[-1]
    last_signal = df["MACD_signal"].iloc[-1]
    
    print(f"Current MACD: {last_macd:.4f}")
    print(f"Current Signal: {last_signal:.4f}")
    
    if last_macd > last_signal:
        print("Signal: Bullish momentum -> upward trend likely continuing")
    else:
        print("Signal: Bearish momentum -> downward pressure or weakening trend")
# Out:
# ============================================================
# AAPL - MACD INTERPRETATION
# ============================================================
# Bullish periods (MACD > Signal): 1890 (50.5%)
# Bearish periods (MACD < Signal): 1851 (49.5%)
#
# Current MACD: 1.5595
# Current Signal: 2.4246
# Signal: Bearish momentum -> downward pressure or weakening trend
#
# ============================================================
# AMZN - MACD INTERPRETATION
# ============================================================
# Bullish periods (MACD > Signal): 1852 (49.5%)
# Bearish periods (MACD < Signal): 1889 (50.5%)
#
# Current MACD: 2.7820
# Current Signal: 2.9230
# Signal: Bearish momentum -> downward pressure or weakening trend
#
# ============================================================
# GOOG - MACD INTERPRETATION
# ============================================================
# Bullish periods (MACD > Signal): 1956 (52.3%)
# Bearish periods (MACD < Signal): 1785 (47.7%)
#
# Current MACD: 1.8428
# Current Signal: 1.3059
# Signal: Bullish momentum -> upward trend likely continuing
#
# ============================================================
# META - MACD INTERPRETATION
# ============================================================
# Bullish periods (MACD > Signal): 1481 (51.2%)
# Bearish periods (MACD < Signal): 1409 (48.8%)
#
# Current MACD: 8.1933
# Current Signal: 6.6935
# Signal: Bullish momentum -> upward trend likely continuing
#
# ============================================================
# NVDA - MACD INTERPRETATION
# ============================================================
# Bullish periods (MACD > Signal): 1939 (51.8%)
# Bearish periods (MACD < Signal): 1802 (48.2%)
#
# Current MACD: 0.6975
# Current Signal: 0.6352
# Signal: Bullish momentum -> upward trend likely continuing
